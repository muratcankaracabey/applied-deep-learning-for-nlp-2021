# %%
CLIENT_SECRETS_FILE = "client_secret.json"

SCOPES = ['https://www.googleapis.com/auth/youtube.force-ssl']
API_SERVICE_NAME = 'youtube'
API_VERSION = 'v3'

import os
import pickle
import google.oauth2.credentials
 
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
 
 
def get_authenticated_service():
    credentials = None
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            credentials = pickle.load(token)
    #  Check if the credentials are invalid or do not exist
    if not credentials or not credentials.valid:
        # Check if the credentials have expired
        if credentials and credentials.expired and credentials.refresh_token:
            credentials.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                CLIENT_SECRETS_FILE, SCOPES)
            credentials = flow.run_console()

        # Save the credentials for the next run
        with open('token.pickle', 'wb') as token:
            pickle.dump(credentials, token)

    return build(API_SERVICE_NAME, API_VERSION, credentials = credentials)

# %%
os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
youtube = get_authenticated_service()

# %% [markdown]
# ### getting playlist id for the channel

# %%
channel_content = youtube.channels().list(part="contentDetails",forUsername="cnbc").execute()
playlist_id = channel_content['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# %% [markdown]
# ### extract only 50 videos

# %%
#getting videos from the playlist (with maxResults = 50, only 50 video included in the response)
#with using next page token new videos can be extracted
videos = youtube.playlistItems().list(part="snippet",maxResults=50,playlistId=playlist_id).execute()

# %%
len(videos['items'])
# Out:
# 50

# %% [markdown]
# ### extract only 5 top comments for each video

# %%
data_dict = dict()
i = 0
for item in videos['items']:
    video_id = item['snippet']['resourceId']['videoId']
    video_title = item['snippet']['title']
    comment_threads = youtube.commentThreads().list(part="snippet",
                                                            maxResults = 5,
                                                            videoId = video_id).execute()
    for comment_thread in comment_threads['items']:
        comment = comment_thread['snippet']['topLevelComment']['snippet']['textDisplay']
        like_count = comment_thread['snippet']['topLevelComment']['snippet']['likeCount']
        data_dict[i] = {'video_id':video_id,
                        'video_title':video_title,
                        'comment':comment,
                        'like_count':like_count}
        i += 1

# %%
import pandas as pd

pd.DataFrame.from_dict(data_dict, "index")
# Out:
#         video_id                                        video_title  \
# 0    SihcAYubbqk  How airlines like United are using passenger p...
# 1    SihcAYubbqk  How airlines like United are using passenger p...
# 2    SihcAYubbqk  How airlines like United are using passenger p...
# 3    SihcAYubbqk  How airlines like United are using passenger p...
# 4    SihcAYubbqk  How airlines like United are using passenger p...
# ..           ...                                                ...
# 242  SKqPT96iY08  Why Gun Sales Are Surging Ahead Of The Electio...
# 243  SKqPT96iY08  Why Gun Sales Are Surging Ahead Of The Electio...
# 244  SKqPT96iY08  Why Gun Sales Are Surging Ahead Of The Electio...
# 245  SKqPT96iY08  Why Gun Sales Are Surging Ahead Of The Electio...
# 246  SKqPT96iY08  Why Gun Sales Are Surging Ahead Of The Electio...
#
#                                                comment  like_count
# 0    ... . End  COVID-19 … Now.  Directory of  Doct...           0
# 1    That&#39;s ridiculous 😂😂😂<br />I am just glad ...           6
# 2    only kind of passengers who don&#39;t complain...           0
# 3    At least they are not risking delivery with Bo...           0
# 4    The “stars” on Spotify are hardly at the level...           1
# ..                                                 ...         ...
# 242  Merry Christmas! The hottest discounts on the ...           0
# 243  I had a dream that the Press Corp and media we...           0
# 244                  Peaceful transfer of voter fraud.           0
# 245  After i lost the only job i had, i became worr...           0
# 246  Why gun sales are surging?!....blm and Seattle...           0
#
# [247 rows x 4 columns]

# %% [markdown]
# ### extract last 5 videos but all top comment threads by using paging

# %%
videos = youtube.playlistItems().list(part="snippet",
                                      maxResults=5,
                                      playlistId=playlist_id).execute()
data_dict = dict()
i = 0
for item in videos['items']:
    video_id = item['snippet']['resourceId']['videoId']
    video_title = item['snippet']['title']
    
    
    first_page = True
    page_token = None
    nextPageExist = True
    while nextPageExist:
        if first_page:
            comment_threads = youtube.commentThreads().list(part="snippet",
                                                            maxResults = 50,
                                                            videoId = video_id).execute()
            first_page = False
        
        else:
            comment_threads = youtube.commentThreads().list(part="snippet",
                                                            maxResults = 50,
                                                            pageToken = page_token,
                                                            videoId = video_id).execute()
            
        for comment_thread in comment_threads['items']:
            comment = comment_thread['snippet']['topLevelComment']['snippet']['textDisplay']
            like_count = comment_thread['snippet']['topLevelComment']['snippet']['likeCount']
            data_dict[i] = {'video_id':video_id,
                            'video_title':video_title,
                            'comment':comment,
                            'like_count':like_count}
            i += 1
        
        if 'nextPageToken' in comment_threads:
            nextPageExist = True
            page_token = comment_threads['nextPageToken']
        else:
            nextPageExist = False

# %%
pd.DataFrame.from_dict(data_dict, "index").sort_values(by=['like_count'],ascending=False)
# Out:
#          video_id                                  video_title  \
# 1747  wkd7QFPDJL4  Why Teachers Are Paid So Little In The U.S.
# 2306  wkd7QFPDJL4  Why Teachers Are Paid So Little In The U.S.
# 2265  wkd7QFPDJL4  Why Teachers Are Paid So Little In The U.S.
# 1630  wkd7QFPDJL4  Why Teachers Are Paid So Little In The U.S.
# 1873  wkd7QFPDJL4  Why Teachers Are Paid So Little In The U.S.
# ...           ...                                          ...
# 987   wkd7QFPDJL4  Why Teachers Are Paid So Little In The U.S.
# 986   wkd7QFPDJL4  Why Teachers Are Paid So Little In The U.S.
# 984   wkd7QFPDJL4  Why Teachers Are Paid So Little In The U.S.
# 983   wkd7QFPDJL4  Why Teachers Are Paid So Little In The U.S.
# 1171  wkd7QFPDJL4  Why Teachers Are Paid So Little In The U.S.
#
#                                                 comment  like_count
# 1747  It&#39;s not due to the lack of funds. Somebod...        2249
# 2306  The short of it: You pay for what you value. A...        1601
# 2265  Education simply isn&#39;t a priority, that is...        1596
# 1630  No wonder why Walter White from Breaking Bad g...        1493
# 1873  A nation with a bad education system is a doom...        1151
# ...                                                 ...         ...
# 987   Teachers should get paid a minimum of 60k a ye...           0
# 986                                     supply / demand           0
# 984   We ask teachers to prepare our kids to be the ...           0
# 983   The government wants people poor, and they wan...           0
# 1171  Well this report really revealed that they are...           0
#
# [2342 rows x 4 columns]

# %% [markdown]
# ### extract top comments and the replies(top 50 reply) to the comment in a video

# %%
videos = youtube.playlistItems().list(part="snippet",
                                      maxResults=5,
                                      playlistId=playlist_id).execute()
data_dict = dict()
i = 0
for video in videos['items']:
    video_id = video['snippet']['resourceId']['videoId']
    video_title = video['snippet']['title']
    
    
    first_page = True
    page_token = None
    nextPageExist = True
    while nextPageExist:
        if first_page:
            comment_threads = youtube.commentThreads().list(part="snippet",
                                                            maxResults = 50,
                                                            videoId = video_id).execute()
            first_page = False
        
        else:
            comment_threads = youtube.commentThreads().list(part="snippet",
                                                            maxResults = 50,
                                                            pageToken = page_token,
                                                            videoId = video_id).execute()
            
        for comment_thread in comment_threads['items']:
            
            comment = comment_thread['snippet']['topLevelComment']['snippet']['textDisplay']
            like_count = comment_thread['snippet']['topLevelComment']['snippet']['likeCount']
            parent_id = comment_thread['snippet']['topLevelComment']['id']
            
            reply_comments = youtube.comments().list(part="snippet",
                                                  maxResults = 50,
                                                  parentId=parent_id).execute()
            data_dict[i] = {'channel':'cnbc',
                            'video_title':video_title,
                            'video_id':video_id,
                            'comment':comment,
                            'like_count':like_count,
                            'reply_to':''}
            i += 1
            for reply_comment in reply_comments['items']:
                reply_comment_text = reply_comment['snippet']['textDisplay']
                reply_like_count = reply_comment['snippet']['likeCount']
                
                data_dict[i] = {'channel':'cnbc',
                                'video_title':video_title,
                                'video_id':video_id,
                                'comment':reply_comment_text,
                                'like_count':reply_like_count,
                                'reply_to':comment}
                i += 1
        
        if 'nextPageToken' in comment_threads:
            nextPageExist = True
            page_token = comment_threads['nextPageToken']
        else:
            nextPageExist = False

# %%
df=pd.DataFrame.from_dict(data_dict, "index").sort_values(by=['like_count'],ascending=False)

# %%
df[df['reply_to'] == df.iloc[0]['comment']]
# Out:
#     channel                                        video_title     video_id  \
# 467    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 466    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 465    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 463    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 462    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 461    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 459    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 451    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 455    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 458    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 450    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 452    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 453    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 454    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 456    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 457    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 460    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 464    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 449    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 448    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 447    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 446    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 434    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 435    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 436    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 437    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 438    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 439    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 440    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 441    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 442    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 443    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 444    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
# 445    cnbc  Disney Stock Hits An All-Time High As Disney+ ...  DO45Y6ydKhU
#
#                                                comment  like_count  \
# 467  I can&#39;t wait anymore, I need a really prof...           3
# 466  I must say, I speculated in both stock and for...           2
# 465  Stock is good  but forex market is in good sha...           1
# 463  I keep loosing really don&#39;t understand how...           1
# 462  I just withdraw my profit last two days before...           1
# 461  I saw the recommendation but I didn&#39;t both...           1
# 459  Thanks Jordan … I did invest with them after I...           1
# 451  Baldwin is a genius this is my 11th win with h...           1
# 455  Woow am so shocked you all know that lady.. me...           1
# 458  Hahhhaha if you&#39;ve not heard about her the...           1
# 450  Am glad I got recommended to her she is the be...           0
# 452  Please someone should help here ... I lost 750...           0
# 453                            +.1.4.0.8.3.1.7.3.7.0.4           0
# 454  @ hahaha you don&#39;t  need to be shocked Bal...           0
# 456  @                     she is expert mrs. Baldw...           0
# 457                    Her availability is on Whats@pp           0
# 460  Who is this professional broker everyone is ta...           0
# 464  Hey Jordan I did invest with her and I made  h...           0
# 449  Only the real investors will understand how go...           0
# 448  I have seen so many recommendations about her ...           0
# 447  Trust me she is very awesome 👌she has managed ...           0
# 446  Initially no doubts expert mrs  Baldwin  is th...           0
# 434  when it comes to investing on disney shares , ...           0
# 435  For what will it profit a man if he gains the ...           0
# 436  Well most problems of traders is  overtrading ...           0
# 437      Always go with what you can afford to loose..           0
# 438                 Stock is good but I prefer forex..           0
# 439  Wow congrats I&#39;m looking up for a 1000 $ i...           0
# 440  That&#39;s the more reason you should reach ou...           0
# 441  Forex/ stock is the best investment anyone cou...           0
# 442         Am from Africa can she  be of help to me ?           0
# 443  Am from Dubai and I have been able to make qui...           0
# 444  I met her in London at conference after That I...           0
# 445  Yeah I met in the aspect of stocks she is quit...           0
#
#                                               reply_to
# 467  Trading isn&#39;t easy to my best of knowledge...
# 466  Trading isn&#39;t easy to my best of knowledge...
# 465  Trading isn&#39;t easy to my best of knowledge...
# 463  Trading isn&#39;t easy to my best of knowledge...
# 462  Trading isn&#39;t easy to my best of knowledge...
# 461  Trading isn&#39;t easy to my best of knowledge...
# 459  Trading isn&#39;t easy to my best of knowledge...
# 451  Trading isn&#39;t easy to my best of knowledge...
# 455  Trading isn&#39;t easy to my best of knowledge...
# 458  Trading isn&#39;t easy to my best of knowledge...
# 450  Trading isn&#39;t easy to my best of knowledge...
# 452  Trading isn&#39;t easy to my best of knowledge...
# 453  Trading isn&#39;t easy to my best of knowledge...
# 454  Trading isn&#39;t easy to my best of knowledge...
# 456  Trading isn&#39;t easy to my best of knowledge...
# 457  Trading isn&#39;t easy to my best of knowledge...
# 460  Trading isn&#39;t easy to my best of knowledge...
# 464  Trading isn&#39;t easy to my best of knowledge...
# 449  Trading isn&#39;t easy to my best of knowledge...
# 448  Trading isn&#39;t easy to my best of knowledge...
# 447  Trading isn&#39;t easy to my best of knowledge...
# 446  Trading isn&#39;t easy to my best of knowledge...
# 434  Trading isn&#39;t easy to my best of knowledge...
# 435  Trading isn&#39;t easy to my best of knowledge...
# 436  Trading isn&#39;t easy to my best of knowledge...
# 437  Trading isn&#39;t easy to my best of knowledge...
# 438  Trading isn&#39;t easy to my best of knowledge...
# 439  Trading isn&#39;t easy to my best of knowledge...
# 440  Trading isn&#39;t easy to my best of knowledge...
# 441  Trading isn&#39;t easy to my best of knowledge...
# 442  Trading isn&#39;t easy to my best of knowledge...
# 443  Trading isn&#39;t easy to my best of knowledge...
# 444  Trading isn&#39;t easy to my best of knowledge...
# 445  Trading isn&#39;t easy to my best of knowledge...
